# %% [markdown]
# # Importação

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# # Coletando dados

# %%
covid = pd.read_html("https://www.statista.com/statistics/1104709/coronavirus-deaths-worldwide-per-million-inhabitants/")[0]

# %%
covid.rename(columns={"Unnamed: 0":"Country"}, inplace=True)

# %%
covid.head(30)
# Out:
#                    Country  Confirmed cases (absolute)  Cases in last 7 days  \
# 0                  Belgium                      760809                 14507
# 1                  Czechia                     1184352                 61100
# 2                 Slovenia                      187005                  4521
# 3          United Kingdom¹                     4132452                 61159
# 4                    Italy                     2848564                 83152
# 5                 Portugal                      800586                  7757
# 6                     USA¹                    28225001                433941
# 7   Bosnia and Herzegovina                      129753                  2618
# 8                  Hungary                      410129                 16106
# 9          North Macedonia                      100632                  2458
# 10                   Spain                     3170644                 48957
# 11                 Moldova                      180150                  5995
# 12                Bulgaria                      242124                  7696
# 13                  Mexico                     2060908                 38246
# 14                    Peru                     1293497                 41360
# 15                  Panama                      338701                  4238
# 16                 Croatia                      241048                  2182
# 17                 France¹                     3565621                119737
# 18                  Sweden                      647470                 20448
# 19                Slovakia                      298337                 12918
# 20                  Brazil                    10324463                293837
# 21                Colombia                     2237542                 25017
# 22             Switzerland                      552698                  5944
# 23               Argentina                     2085411                 38616
# 24               Lithuania                      195481                  3288
# 25                  Poland                     1661109                 46663
# 26                 Armenia                      170945                  1125
# 27                   Chile                      807872                 19730
# 28                 Romania                      788048                 16205
# 29                 Bolivia                      245719                  6195
#
#     Confirmed deaths (absolute)  Deaths in last 7 days  \
# 0                         21988                    167
# 1                         19682                    943
# 2                          3802                     47
# 3                        121516                   2356
# 4                         96666                   1779
# 5                         16136                    382
# 6                        503726                  12669
# 7                          5051                     89
# 8                         14552                    517
# 9                          3098                     80
# 10                        68468                   1764
# 11                         3846                    129
# 12                        10026                    240
# 13                       182815                   4707
# 14                        45487                   1179
# 15                         5789                     95
# 16                         5477                     78
# 17                        84295                   1887
# 18                        12793                    195
# 19                         6775                    504
# 20                       249957                   6500
# 21                        59260                    926
# 22                         9942                     66
# 23                        51650                    793
# 24                         3200                     71
# 25                        42808                   1226
# 26                         3175                     19
# 27                        20173                    375
# 28                        20086                    427
# 29                        11547                    194
#
#     Daily increase (# deaths)  Population (in millions)  \
# 0                          32                     11.48
# 1                         145                     10.67
# 2                          10                      2.09
# 3                         442                     66.83
# 4                         318                     60.30
# 5                          50                     10.27
# 6                        3202                    328.24
# 7                          17                      3.30
# 8                         102                      9.77
# 9                          13                      2.08
# 10                        389                     47.08
# 11                       3846                      2.66
# 12                         48                      6.98
# 13                       1006                    127.58
# 14                        224                     32.51
# 15                         17                      4.25
# 16                         15                      4.07
# 17                        270                     67.06
# 18                         80                     10.29
# 19                        104                      5.45
# 20                       1428                    211.05
# 21                        142                     50.34
# 22                         12                      8.57
# 23                        140                     44.94
# 24                         11                      2.79
# 25                        372                     37.97
# 26                          4                      2.96
# 27                         22                     18.95
# 28                         73                     19.36
# 29                         39                     11.51
#
#     Deaths per million (total)  Deaths per million (last 7 days)
# 0                      1914.65                             14.54
# 1                      1844.66                             88.38
# 2                      1820.93                             22.51
# 3                      1818.17                             35.25
# 4                      1603.15                             29.50
# 5                      1571.27                             37.20
# 6                      1534.63                             38.60
# 7                      1530.14                             26.96
# 8                      1489.47                             52.92
# 9                      1486.95                             38.40
# 10                     1454.39                             37.47
# 11                     1447.15                             48.54
# 12                     1437.26                             34.40
# 13                     1432.99                             36.90
# 14                     1399.15                             36.27
# 15                     1363.26                             22.37
# 16                     1346.53                             19.18
# 17                     1257.01                             28.14
# 18                     1243.80                             18.96
# 19                     1242.19                             92.41
# 20                     1184.35                             30.80
# 21                     1177.21                             18.40
# 22                     1159.44                              7.70
# 23                     1149.34                             17.65
# 24                     1148.25                             25.48
# 25                     1127.39                             32.29
# 26                     1073.46                              6.42
# 27                     1064.42                             19.79
# 28                     1037.69                             22.06
# 29                     1002.94                             16.85

# %% [markdown]
# # Análise

# %%
covid.sort_values("Deaths per million (last 7 days)", ascending=False).head()
# Out:
#      Country  Confirmed cases (absolute)  Cases in last 7 days  \
# 19  Slovakia                      298337                 12918
# 1    Czechia                     1184352                 61100
# 8    Hungary                      410129                 16106
# 11   Moldova                      180150                  5995
# 41   Lebanon                      362850                 14040
#
#     Confirmed deaths (absolute)  Deaths in last 7 days  \
# 19                         6775                    504
# 1                         19682                    943
# 8                         14552                    517
# 11                         3846                    129
# 41                         4508                    302
#
#     Daily increase (# deaths)  Population (in millions)  \
# 19                        104                      5.45
# 1                         145                     10.67
# 8                         102                      9.77
# 11                       3846                      2.66
# 41                         62                      6.86
#
#     Deaths per million (total)  Deaths per million (last 7 days)
# 19                     1242.19                             92.41
# 1                      1844.66                             88.38
# 8                      1489.47                             52.92
# 11                     1447.15                             48.54
# 41                      657.55                             44.05

# %%
covid[["Cases in last 7 days", "Deaths in last 7 days"]].corr()
# Out:
#                        Cases in last 7 days  Deaths in last 7 days
# Cases in last 7 days               1.000000               0.941965
# Deaths in last 7 days              0.941965               1.000000

# %%
covid[["Cases in last 7 days", "Population (in millions)"]].corr()
# Out:
#                           Cases in last 7 days  Population (in millions)
# Cases in last 7 days                  1.000000                  0.261456
# Population (in millions)              0.261456                  1.000000

# %% [markdown]
# # Predição

# %%
from sklearn import linear_model

# Dividir os dados em conjutos de treinando/treinados
covid_treinando = covid[["Country", "Cases in last 7 days", "Deaths in last 7 days"]][:152]
covid_treinados = covid[["Country", "Cases in last 7 days", "Deaths in last 7 days"]][1:31]

covid_x_treinando = covid_treinando[["Cases in last 7 days"]]
covid_x_treinados = covid_treinados[["Cases in last 7 days"]]

covid_y_treinando = covid_treinando[["Deaths in last 7 days"]]
covid_y_treinados = covid_treinados[["Deaths in last 7 days"]]

# Criando um objeto de regressão linear
rl = linear_model.LinearRegression()

# Treinar o modelo usando um conjunto de dados
rl.fit(covid_x_treinando, covid_y_treinando)

# Fazer a predição usando os dados de treinados
covid_y_pred = rl.predict(covid_x_treinados)

# %%
covid_treinados['Predição'] = covid_y_pred

# %%
covid_treinados['Predição'] = covid_treinados['Predição'].apply(lambda x: 0 if x<0 else x)

# %%
covid_treinados.head()
# Out:
#            Country  Cases in last 7 days  Deaths in last 7 days     Predição
# 1          Czechia                 61100                    943  1584.180628
# 2         Slovenia                  4521                     47    97.645480
# 3  United Kingdom¹                 61159                   2356  1585.730771
# 4            Italy                 83152                   1779  2163.566497
# 5         Portugal                  7757                    382   182.666914

# %%
covid_treinados.sort_values("Predição", ascending=False).head()
# Out:
#             Country  Cases in last 7 days  Deaths in last 7 days      Predição
# 6              USA¹                433941                  12669  11380.063393
# 20           Brazil                293837                   6500   7699.024133
# 17          France¹                119737                   1887   3124.786885
# 4             Italy                 83152                   1779   2163.566497
# 3   United Kingdom¹                 61159                   2356   1585.730771

# %%
brazil = covid_treinados.loc[covid_treinados['Country'] == 'Brazil']
print(brazil)
# Out:
#    Country  Cases in last 7 days  Deaths in last 7 days     Predição
# 20  Brazil                293837                   6500  7699.024133

# %%
covid_dif_treinados = abs(covid_treinados['Deaths in last 7 days'] - covid_treinados['Predição'])

# %%
covid_dif_treinados.describe()
# Out:
# count      30.000000
# mean      393.713438
# std       733.823419
# min         4.789954
# 25%        41.467043
# 50%       114.217632
# 75%       368.701229
# max      3723.276684
# dtype: float64
